# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanedykane/litoX/blob/main/SP_ML/ml_measurements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PREPROCESSING**

# %% [markdown]
# ## Setting up environment

# %%
## Data analysis and wrangling
import numpy as np
import pandas as pd
import random as rnd
import matplotlib.pyplot as plt
import seaborn as sns

## Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import set_config
# %matplotlib inline

## Preprocessing
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Load and Preprocess Data

# %% [markdown]
# MALE DATASET PREPROCESSING

# %%
## from github
male_url = "https://raw.githubusercontent.com/Geez-l/litoX/main/SP_ML/datasets/male.csv"
male_litob = pd.read_csv(male_url)

male_litob.head(-1)
# Out:
#      Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0      110004    43.1  33.05   28.15         21                 28.5
# 1      120004    43.1  33.05   28.15         21                 28.5
# 2      130004    43.1  33.05   28.15         21                 28.5
# 3      140004    43.1  33.05   28.15         21                 28.5
# 4      150004    43.1  33.05   28.15         21                 28.5
# ..        ...     ...    ...     ...        ...                  ...
# 859    110261    47.2  31.65   32.05         21                 33.7
# 860    120261    47.2  31.65   32.05         21                 33.7
# 861    130261    47.2  31.65   32.05         21                 33.7
# 862    140261    47.2  31.65   32.05         21                 33.7
# 863    150261    47.2  31.65   32.05         21                 33.7
#
#      Distance Umbos  Umbos Right  Umbos Left
# 0              3.05          NaN         NaN
# 1              3.05          NaN         NaN
# ...

# %% [markdown]
# Dropping unused columns

# %%
male_litob = male_litob.drop(columns=['Umbos Right', 'Umbos Left'])
male_litob.head(-1)
# Out:
#      Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0      110004    43.1  33.05   28.15         21                 28.5
# 1      120004    43.1  33.05   28.15         21                 28.5
# 2      130004    43.1  33.05   28.15         21                 28.5
# 3      140004    43.1  33.05   28.15         21                 28.5
# 4      150004    43.1  33.05   28.15         21                 28.5
# ..        ...     ...    ...     ...        ...                  ...
# 859    110261    47.2  31.65   32.05         21                 33.7
# 860    120261    47.2  31.65   32.05         21                 33.7
# 861    130261    47.2  31.65   32.05         21                 33.7
# 862    140261    47.2  31.65   32.05         21                 33.7
# 863    150261    47.2  31.65   32.05         21                 33.7
#
#      Distance Umbos
# 0              3.05
# 1              3.05
# 2              3.05
# 3              3.05
# 4              3.05
# ...

# %% [markdown]
# Dropping nan values

# %%
## drops nan
male_litob = male_litob.dropna()
male_litob
# Out:
#      Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0      110004    43.1  33.05   28.15         21                 28.5
# 1      120004    43.1  33.05   28.15         21                 28.5
# 2      130004    43.1  33.05   28.15         21                 28.5
# 3      140004    43.1  33.05   28.15         21                 28.5
# 4      150004    43.1  33.05   28.15         21                 28.5
# ..        ...     ...    ...     ...        ...                  ...
# 860    120261    47.2  31.65   32.05         21                 33.7
# 861    130261    47.2  31.65   32.05         21                 33.7
# 862    140261    47.2  31.65   32.05         21                 33.7
# 863    150261    47.2  31.65   32.05         21                 33.7
# 864    160261    47.2  31.65   32.05         21                 33.7
#
#      Distance Umbos
# 0              3.05
# 1              3.05
# 2              3.05
# 3              3.05
# 4              3.05
# ...

# %% [markdown]
# Create other features a. LW_ratio and b. LH_ratio

# %%
## feature engineering
male_litob['LW_ratio']= male_litob['Length'] / male_litob['Width']
male_litob['LH_ratio'] = male_litob['Length'] / male_litob['Height']
male_litob['WH_ratio'] = male_litob['Width'] / male_litob['Height']
# male_litob['DU_ratio'] = male_litob['Distance Umbos'] / male_litob['Height']
male_litob['UL_ratio'] = male_litob['Distance Umbos'] / male_litob['Length']
male_litob['HL_ratio'] = male_litob['Length (Hinge Line)'] / male_litob['Length']
male_litob['UH_ratio'] = male_litob['Distance Umbos'] / male_litob['Height']
male_litob['Rib Density'] = male_litob['Rib count'] / male_litob['Length']

male_litob
# Out:
#      Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0      110004    43.1  33.05   28.15         21                 28.5
# 1      120004    43.1  33.05   28.15         21                 28.5
# 2      130004    43.1  33.05   28.15         21                 28.5
# 3      140004    43.1  33.05   28.15         21                 28.5
# 4      150004    43.1  33.05   28.15         21                 28.5
# ..        ...     ...    ...     ...        ...                  ...
# 860    120261    47.2  31.65   32.05         21                 33.7
# 861    130261    47.2  31.65   32.05         21                 33.7
# 862    140261    47.2  31.65   32.05         21                 33.7
# 863    150261    47.2  31.65   32.05         21                 33.7
# 864    160261    47.2  31.65   32.05         21                 33.7
#
#      Distance Umbos  LW_ratio  LH_ratio  WH_ratio  UL_ratio  HL_ratio  \
# ...

# %% [markdown]
# Preprocessing to keep only the unique instances

# %%
## extracts last three digits (unique in dataset)

male_litob["Base_ID"] = male_litob["Litob_id"] % 1000

## keeps only the first occurrence of each Base_ID
male_litob_unique = male_litob.drop_duplicates(subset="Base_ID", keep="first").drop(columns=["Base_ID"])

# keep only rows where Litob_id starts with 110XXX
male_litob_unique = male_litob_unique[male_litob_unique["Litob_id"] // 1000 == 110]
male_litob_unique.drop(columns=['Unnamed:0'], inplace=True, errors='ignore')

male_litob_unique.head(-1)
# Out:
#      Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0      110004   43.10  33.05   28.15         21                28.50
# 6      110005   41.10  31.05   27.60         20                23.05
# 12     110006   43.20  33.45   29.35         20                29.35
# 18     110007   41.50  32.55   27.70         20                24.10
# 24     110008   42.20  33.05   27.70         21                24.05
# ..        ...     ...    ...     ...        ...                  ...
# 829    110256   50.30  37.05   37.05         20                32.20
# 835    110257   57.30  42.75   38.45         20                38.30
# 841    110258   47.15  36.40   34.05         19                32.25
# 847    110259   43.05  31.50   28.05         19                28.60
# 853    110260   52.40  39.05   36.05         21                34.20
#
#      Distance Umbos  LW_ratio  LH_ratio  WH_ratio  UL_ratio  HL_ratio  \
# ...

# %% [markdown]
# Checking and debugging purposes

# %%
male_litob_unique.columns
# Out:
# Index(['Litob_id', 'Length', 'Width', 'Height', 'Rib count',
#        'Length (Hinge Line)', 'Distance Umbos', 'LW_ratio', 'LH_ratio',
#        'WH_ratio', 'UL_ratio', 'HL_ratio', 'UH_ratio', 'Rib Density'],
#       dtype='object')

# %%
# from google.colab import files
# male_litob_unique.to_csv('male_litob_unique.csv', encoding = 'utf-8-sig')
# files.download('male_litob_unique.csv')

# %% [markdown]
# FEMALE DATASET PREPROCESSING

# %%
## from github
female_url = "https://raw.githubusercontent.com/Geez-l/litoX/main/SP_ML/datasets/female.csv"
female_litob = pd.read_csv(female_url)

female_litob.head(-1)
# Out:
#      Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0       10001   48.05  37.60   32.15         20                33.55
# 1       20001   48.05  37.60   32.15         20                33.55
# 2       30001   48.05  37.60   32.15         20                33.55
# 3       40001   48.05  37.60   32.15         20                33.55
# 4       50001   48.05  37.60   32.15         20                33.55
# ..        ...     ...    ...     ...        ...                  ...
# 755     10271   50.05  36.55   35.05         20                33.70
# 756     20271   50.05  36.55   35.05         20                33.70
# 757     30271   50.05  36.55   35.05         20                33.70
# 758     40271   50.05  36.55   35.05         20                33.70
# 759     50271   50.05  36.55   35.05         20                33.70
#
#      Distance Umbos  Umbos Right  Umbos Left
# 0               4.1          NaN         NaN
# 1               4.1          NaN         NaN
# ...

# %% [markdown]
# Dropping unused columns

# %%
## drops umbos right and left
female_litob = female_litob.drop(columns=['Umbos Right', 'Umbos Left'])
female_litob.head(-1)
# Out:
#      Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0       10001   48.05  37.60   32.15         20                33.55
# 1       20001   48.05  37.60   32.15         20                33.55
# 2       30001   48.05  37.60   32.15         20                33.55
# 3       40001   48.05  37.60   32.15         20                33.55
# 4       50001   48.05  37.60   32.15         20                33.55
# ..        ...     ...    ...     ...        ...                  ...
# 755     10271   50.05  36.55   35.05         20                33.70
# 756     20271   50.05  36.55   35.05         20                33.70
# 757     30271   50.05  36.55   35.05         20                33.70
# 758     40271   50.05  36.55   35.05         20                33.70
# 759     50271   50.05  36.55   35.05         20                33.70
#
#      Distance Umbos
# 0               4.1
# 1               4.1
# 2               4.1
# 3               4.1
# 4               4.1
# ...

# %% [markdown]
# Dropping nan values

# %%
## drops NaN values
female_litob = female_litob.dropna()
female_litob
# Out:
#      Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0       10001   48.05  37.60   32.15         20                33.55
# 1       20001   48.05  37.60   32.15         20                33.55
# 2       30001   48.05  37.60   32.15         20                33.55
# 3       40001   48.05  37.60   32.15         20                33.55
# 4       50001   48.05  37.60   32.15         20                33.55
# ..        ...     ...    ...     ...        ...                  ...
# 756     20271   50.05  36.55   35.05         20                33.70
# 757     30271   50.05  36.55   35.05         20                33.70
# 758     40271   50.05  36.55   35.05         20                33.70
# 759     50271   50.05  36.55   35.05         20                33.70
# 760     60271   50.05  36.55   35.05         20                33.70
#
#      Distance Umbos
# 0               4.1
# 1               4.1
# 2               4.1
# 3               4.1
# 4               4.1
# ...

# %% [markdown]
# Adding additional features

# %%
## calculating ratios

female_litob['LW_ratio']= female_litob['Length'] / female_litob['Width']
female_litob['LH_ratio'] = female_litob['Length'] / female_litob['Height']
female_litob['WH_ratio'] = female_litob['Width'] / female_litob['Height']
# female_litob['DU_ratio'] = female_litob['Distance Umbos'] / female_litob['Height']
female_litob['UL_ratio'] = female_litob['Distance Umbos'] / female_litob['Length']
female_litob['HL_ratio'] = female_litob['Length (Hinge Line)'] / female_litob['Length']
female_litob['UH_ratio'] = female_litob['Distance Umbos'] / female_litob['Height']
female_litob['Rib Density'] = female_litob['Rib count'] / female_litob['Length']

female_litob
# Out:
#      Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0       10001   48.05  37.60   32.15         20                33.55
# 1       20001   48.05  37.60   32.15         20                33.55
# 2       30001   48.05  37.60   32.15         20                33.55
# 3       40001   48.05  37.60   32.15         20                33.55
# 4       50001   48.05  37.60   32.15         20                33.55
# ..        ...     ...    ...     ...        ...                  ...
# 756     20271   50.05  36.55   35.05         20                33.70
# 757     30271   50.05  36.55   35.05         20                33.70
# 758     40271   50.05  36.55   35.05         20                33.70
# 759     50271   50.05  36.55   35.05         20                33.70
# 760     60271   50.05  36.55   35.05         20                33.70
#
#      Distance Umbos  LW_ratio  LH_ratio  WH_ratio  UL_ratio  HL_ratio  \
# ...

# %% [markdown]
# Keeping unique instances in female dataset

# %%
## extracts last 3 digits since its unique in dataset
female_litob["Base_ID"] = female_litob["Litob_id"] % 1000

## keeps only the first occurrence of each Base_ID
female_litob_unique = female_litob.drop_duplicates(subset="Base_ID", keep="first").drop(columns=["Base_ID"])

# keep only rows where Litob_id starts with 01XXX
female_litob_unique = female_litob_unique[female_litob_unique["Litob_id"].astype(str).str.startswith("1")]
female_litob_unique.drop(columns=['Unnamed:0'], inplace=True, errors='ignore')

female_litob_unique.head()
# Out:
#     Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0      10001   48.05  37.60   32.15         20                33.55
# 6      10002   47.40  32.50   32.25         20                33.10
# 12     10003   43.30  34.10   31.25         21                32.05
# 18     10075   50.05  35.05   32.05         21                30.05
# 24     10076   40.25  33.55   32.40         20                29.35
#
#     Distance Umbos  LW_ratio  LH_ratio  WH_ratio  UL_ratio  HL_ratio  \
# 0             4.10  1.277926  1.494557  1.169518  0.085328  0.698231
# 6             3.05  1.458462  1.469767  1.007752  0.064346  0.698312
# 12            4.50  1.269795  1.385600  1.091200  0.103926  0.740185
# 18            4.10  1.427960  1.561622  1.093604  0.081918  0.600400
# 24            3.40  1.199702  1.242284  1.035494  0.084472  0.729193
#
#     UH_ratio  Rib Density
# 0   0.127527     0.416233
# 6   0.094574     0.421941
# 12  0.144000     0.484988
# 18  0.127925     0.419580
# ...

# %% [markdown]
# Checking and debugging purposes

# %%
female_litob_unique.columns
# Out:
# Index(['Litob_id', 'Length', 'Width', 'Height', 'Rib count',
#        'Length (Hinge Line)', 'Distance Umbos', 'LW_ratio', 'LH_ratio',
#        'WH_ratio', 'UL_ratio', 'HL_ratio', 'UH_ratio', 'Rib Density'],
#       dtype='object')

# %%
#from google.colab import files
#female_litob_unique.to_csv('female_litob_unique.csv', encoding = 'utf-8-sig')
#files.download('female_litob_unique.csv')

# %% [markdown]
# ## Assigning labels to the male and female where female = 0 and male = 1

# %%
## labels assigned
female_litob_unique['Label'] = 0
male_litob_unique['Label'] = 1

# %%
## combining male and female datasets
litob_combined = pd.concat([female_litob_unique, male_litob_unique], ignore_index=True)

# Create a temporary Base_ID column for sorting
litob_combined["Base_ID"] = litob_combined["Litob_id"] % 1000

# Sort by Base_ID in increasing order
litob_combined = litob_combined.sort_values(by="Base_ID").reset_index(drop=True)

# Drop the temporary Base_ID column
litob_combined = litob_combined.drop(columns=["Base_ID"])

litob_combined
# Out:
#      Litob_id  Length  Width  Height  Rib count  Length (Hinge Line)  \
# 0       10001   48.05  37.60   32.15         20                33.55
# 1       10002   47.40  32.50   32.25         20                33.10
# 2       10003   43.30  34.10   31.25         21                32.05
# 3      110004   43.10  33.05   28.15         21                28.50
# 4      110005   41.10  31.05   27.60         20                23.05
# ..        ...     ...    ...     ...        ...                  ...
# 266     10267   62.05  47.05   42.05         20                40.15
# 267     10268   63.05  46.30   42.50         20                42.55
# 268     10269   56.40  44.45   40.60         19                38.30
# 269     10270   53.55  39.05   35.05         20                37.05
# 270     10271   50.05  36.55   35.05         20                33.70
#
#      Distance Umbos  LW_ratio  LH_ratio  WH_ratio  UL_ratio  HL_ratio  \
# ...

# %% [markdown]
# remove the litob id

# %%
##  remove Litob_id column

if 'Litob_id' in litob_combined.columns:
    litob_combined = litob_combined.drop('Litob_id', axis=1)

litob_combined
# Out:
#      Length  Width  Height  Rib count  Length (Hinge Line)  Distance Umbos  \
# 0     48.05  37.60   32.15         20                33.55            4.10
# 1     47.40  32.50   32.25         20                33.10            3.05
# 2     43.30  34.10   31.25         21                32.05            4.50
# 3     43.10  33.05   28.15         21                28.50            3.05
# 4     41.10  31.05   27.60         20                23.05            3.35
# ..      ...    ...     ...        ...                  ...             ...
# 266   62.05  47.05   42.05         20                40.15            4.50
# 267   63.05  46.30   42.50         20                42.55            6.05
# 268   56.40  44.45   40.60         19                38.30            4.05
# 269   53.55  39.05   35.05         20                37.05            5.05
# 270   50.05  36.55   35.05         20                33.70            4.60
#
# ...

# %%
# from google.colab import files
# litob_combined.to_csv('litob_combined.csv', encoding = 'utf-8-sig')
# files.download('litob_combined.csv')

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Features assigned

# %%
## assigning features
features = ['Length', 'Width', 'Height', 'Rib count', 'Length (Hinge Line)', 'Distance Umbos', 'LW_ratio', 'LH_ratio', 'WH_ratio', 'UL_ratio', 'HL_ratio', 'UH_ratio', 'Rib Density']
litob_combined[features].head()
# Out:
#    Length  Width  Height  Rib count  Length (Hinge Line)  Distance Umbos  \
# 0   48.05  37.60   32.15         20                33.55            4.10
# 1   47.40  32.50   32.25         20                33.10            3.05
# 2   43.30  34.10   31.25         21                32.05            4.50
# 3   43.10  33.05   28.15         21                28.50            3.05
# 4   41.10  31.05   27.60         20                23.05            3.35
#
#    LW_ratio  LH_ratio  WH_ratio  UL_ratio  HL_ratio  UH_ratio  Rib Density
# 0  1.277926  1.494557  1.169518  0.085328  0.698231  0.127527     0.416233
# 1  1.458462  1.469767  1.007752  0.064346  0.698312  0.094574     0.421941
# 2  1.269795  1.385600  1.091200  0.103926  0.740185  0.144000     0.484988
# 3  1.304085  1.531083  1.174067  0.070766  0.661253  0.108348     0.487239
# 4  1.323671  1.489130  1.125000  0.081509  0.560827  0.121377     0.486618

# %% [markdown]
# STATISTICAL TESTS

# %% [markdown]
# Displaying the distribution, test used, and the implication if there is significant difference or not

# %%
from scipy.stats import shapiro, mannwhitneyu

## alpha level
alpha = 0.05

## features iterated
for feature in features:

    ## normality test
    shapiro_test = shapiro(litob_combined[feature])

    ## display Shapiro-Wilk test results
    print(f"Feature: {feature}")
    print(f"Shapiro-Wilk Test Statistic: {shapiro_test.statistic}")
    print(f"P-value: {shapiro_test.pvalue:.3f}")  # Display with 10 decimal places

    ## interpret the normality test
    if shapiro_test.pvalue > alpha:
        print("Data is normally distributed. Proceeding with independent sample T-test.")

        ## normally distributed, perform an independent sample T-test
        male_data = litob_combined[litob_combined['Label'] == 1][feature]
        female_data = litob_combined[litob_combined['Label'] == 0][feature]

        ## normally distributed = t-test
        print(f"T-test for {feature} not implemented in this code snippet.")
    else:
        ## not normally distributed = mann whitney
        print("Data is not normally distributed. Proceeding with Mann-Whitney U test.")
        male_data = litob_combined[litob_combined['Label'] == 1][feature]
        female_data = litob_combined[litob_combined['Label'] == 0][feature]

        # mann-Whitney U test
        statistic, p_value = mannwhitneyu(male_data, female_data, alternative='two-sided')

        # result MUT
        print(f"Mann-Whitney U Test Statistic: {statistic}")
        print(f"P-value: {p_value:.3f}")

        # interpreting result
        if p_value > alpha:
            print(f"There is no significant difference between the {feature} of male and female litob.\n")
        else:
            print(f"There is a significant difference between the {feature} of male and female litob.\n")
# Out:
# Feature: Length
# Shapiro-Wilk Test Statistic: 0.9411980979853534
# P-value: 0.000
# Data is not normally distributed. Proceeding with Mann-Whitney U test.
# Mann-Whitney U Test Statistic: 8411.0
# P-value: 0.255
# There is no significant difference between the Length of male and female litob.
#
# Feature: Width
# Shapiro-Wilk Test Statistic: 0.9666884968156657
# P-value: 0.000
# Data is not normally distributed. Proceeding with Mann-Whitney U test.
# Mann-Whitney U Test Statistic: 8941.0
# P-value: 0.753
# There is no significant difference between the Width of male and female litob.
#
# Feature: Height
# Shapiro-Wilk Test Statistic: 0.9530418377444827
# P-value: 0.000
# Data is not normally distributed. Proceeding with Mann-Whitney U test.
# Mann-Whitney U Test Statistic: 8154.5
# P-value: 0.124
# There is no significant difference between the Height of male and female litob.
#
# Feature: Rib count
# Shapiro-Wilk Test Statistic: 0.8765733184278328
# P-value: 0.000
# ...

# %% [markdown]
# Dataframe version

# %%
## store results
results = []

## iterate through features
for feature in features:

    # normality test
    shapiro_test = shapiro(litob_combined[feature])
    distribution = "Normal" if shapiro_test.pvalue > alpha else "Non-normal"

    # Perform appropriate test
    male_data = litob_combined[litob_combined['Label'] == 1][feature]
    female_data = litob_combined[litob_combined['Label'] == 0][feature]

    if distribution == "Normal":
        test_used = "T-test (not implemented)"
        p_value = None
        implication = "T-test not performed"
    else:
        test_used = "Mann-Whitney U test"
        statistic, p_value = mannwhitneyu(male_data, female_data, alternative='two-sided')
        implication = "Significant difference" if p_value <= alpha else "No significant difference"

    # append to results list
    results.append([feature, distribution, test_used, p_value, implication])

# result to df
results_df = pd.DataFrame(results, columns=["Variable Name", "Distribution", "Test used", "p-value", "Implication"])
results_df
# Out:
#           Variable Name Distribution            Test used   p-value  \
# 0                Length   Non-normal  Mann-Whitney U test  0.255209
# 1                 Width   Non-normal  Mann-Whitney U test  0.753102
# 2                Height   Non-normal  Mann-Whitney U test  0.124484
# 3             Rib count   Non-normal  Mann-Whitney U test  0.250530
# 4   Length (Hinge Line)   Non-normal  Mann-Whitney U test  0.119601
# 5        Distance Umbos   Non-normal  Mann-Whitney U test  0.034452
# 6              LW_ratio   Non-normal  Mann-Whitney U test  0.010041
# 7              LH_ratio   Non-normal  Mann-Whitney U test  0.613164
# 8              WH_ratio   Non-normal  Mann-Whitney U test  0.003239
# 9              UL_ratio   Non-normal  Mann-Whitney U test  0.045445
# 10             HL_ratio   Non-normal  Mann-Whitney U test  0.118169
# 11             UH_ratio   Non-normal  Mann-Whitney U test  0.048459
# 12          Rib Density   Non-normal  Mann-Whitney U test  0.130325
#
# ...

# %%
# Separate the data by label (0 for female, 1 for male)
female_data = litob_combined[litob_combined['Label'] == 0]
male_data = litob_combined[litob_combined['Label'] == 1]

# Get descriptive statistics for numerical features for each group
desc_stats_female = female_data[features].describe().T
desc_stats_male = male_data[features].describe().T

# Rename columns for clarity
desc_stats_female = desc_stats_female.rename(columns={'mean': 'Female_Mean', 'std': 'Female_Std', 'min': 'Female_Min', 'max': 'Female_Max', '25%': 'Female_25%', '50%': 'Female_50%', '75%': 'Female_75%', 'count': 'Female_Count'})
desc_stats_male = desc_stats_male.rename(columns={'mean': 'Male_Mean', 'std': 'Male_Std', 'min': 'Male_Min', 'max': 'Male_Max', '25%': 'Male_25%', '50%': 'Male_50%', '75%': 'Male_75%', 'count': 'Male_Count'})

# Combine the descriptive statistics into a single DataFrame
descriptive_statistics = pd.concat([desc_stats_female, desc_stats_male], axis=1)

ordered_columns = []
for stat in ['Count', 'Mean', 'Std', 'Min', '25%', '50%', '75%', 'Max']:
    ordered_columns.append(f'Female_{stat}')
    ordered_columns.append(f'Male_{stat}')

descriptive_statistics = descriptive_statistics[ordered_columns]

# Display the table
print("Descriptive Statistics of Features by Sex (Female vs. Male)")
display(descriptive_statistics)
# Out:
# Descriptive Statistics of Features by Sex (Female vs. Male)
#                      Female_Count  Male_Count  Female_Mean  Male_Mean  \
# Length                      127.0       144.0    50.244488  49.051806
# Width                       127.0       144.0    37.954724  37.690347
# Height                      127.0       144.0    34.737795  33.850278
# Rib count                   127.0       144.0    19.740157  19.868056
# Length (Hinge Line)         127.0       144.0    31.974409  30.810139
# Distance Umbos              127.0       144.0     3.801575   3.496528
# LW_ratio                    127.0       144.0     1.326139   1.302775
# LH_ratio                    127.0       144.0     1.448398   1.454107
# WH_ratio                    127.0       144.0     1.093811   1.117163
# UL_ratio                    127.0       144.0     0.074676   0.070176
# HL_ratio                    127.0       144.0     0.633900   0.624956
# ...

# %% [markdown]
# ## Scaling the values

# %%
from sklearn.preprocessing import MinMaxScaler

##  columns to scale excluding the label
cols_to_scale = ['Length', 'Width', 'Height', 'Length (Hinge Line)', 'Distance Umbos', 'LW_ratio', 'LH_ratio', 'WH_ratio', 'UL_ratio', 'HL_ratio', 'UH_ratio', 'Rib Density']

scaler = MinMaxScaler()

# fit and transform the selected columns
litob_combined[cols_to_scale] = scaler.fit_transform(litob_combined[cols_to_scale])

litob_combined
# Out:
#        Length     Width    Height  Rib count  Length (Hinge Line)  \
# 0    0.333333  0.429735  0.339114         20             0.492701
# 1    0.311667  0.221996  0.342967         20             0.476277
# 2    0.175000  0.287169  0.304432         21             0.437956
# 3    0.168333  0.244399  0.184971         21             0.308394
# 4    0.101667  0.162933  0.163776         20             0.109489
# ..        ...       ...       ...        ...                  ...
# 266  0.800000  0.814664  0.720617         20             0.733577
# 267  0.833333  0.784114  0.737958         20             0.821168
# 268  0.611667  0.708758  0.664740         19             0.666058
# 269  0.516667  0.488798  0.450867         20             0.620438
# 270  0.400000  0.386965  0.450867         20             0.498175
#
#      Distance Umbos  LW_ratio  LH_ratio  WH_ratio  UL_ratio  HL_ratio  \
# 0          0.352601  0.282637  0.463827  0.534534  0.528523  0.600949
# ...

# %% [markdown]
# ## Downloading the final dataset

# %%
# from google.colab import files
# litob_combined.to_csv('litob_combined.csv', index=False)
# files.download('litob_combined.csv')

# %% [markdown]
# ## Dataset Inspection and Visualizations

# %%
## checking columns
litob_combined.columns
# Out:
# Index(['Length', 'Width', 'Height', 'Rib count', 'Length (Hinge Line)',
#        'Distance Umbos', 'LW_ratio', 'LH_ratio', 'WH_ratio', 'UL_ratio',
#        'HL_ratio', 'UH_ratio', 'Rib Density', 'Label'],
#       dtype='object')

# %% [markdown]
# Histogram

# %%
litob_combined_explore = litob_combined.drop(columns=['Label'], errors = 'ignore')
litob_combined_explore.hist(figsize = (10, 10))
# Out:
# array([[<Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Width'}>,
#         <Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Rib count'}>],
#        [<Axes: title={'center': 'Length (Hinge Line)'}>,
#         <Axes: title={'center': 'Distance Umbos'}>,
#         <Axes: title={'center': 'LW_ratio'}>,
#         <Axes: title={'center': 'LH_ratio'}>],
#        [<Axes: title={'center': 'WH_ratio'}>,
#         <Axes: title={'center': 'UL_ratio'}>,
#         <Axes: title={'center': 'HL_ratio'}>,
#         <Axes: title={'center': 'UH_ratio'}>],
#        [<Axes: title={'center': 'Rib Density'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# Exploring the mean, std and etc

# %%
litob_combined_explore.describe()
# Out:
#            Length       Width      Height   Rib count  Length (Hinge Line)  \
# count  271.000000  271.000000  271.000000  271.000000           271.000000
# mean     0.385358    0.438462    0.420663   19.808118             0.412619
# std      0.236575    0.219016    0.195854    0.843323             0.223435
# min      0.000000    0.000000    0.000000   17.000000             0.000000
# 25%      0.186667    0.253564    0.280347   19.000000             0.229927
# 50%      0.350000    0.407332    0.375723   20.000000             0.385036
# 75%      0.533333    0.586558    0.540462   20.000000             0.556569
# max      1.000000    1.000000    1.000000   22.000000             1.000000
#
#        Distance Umbos    LW_ratio    LH_ratio    WH_ratio    UL_ratio  \
# count      271.000000  271.000000  271.000000  271.000000  271.000000
# mean         0.299362    0.344628    0.397733    0.418409    0.421039
# std          0.166136    0.118126    0.132646    0.119395    0.190501
# ...

# %%
litob_combined.Label.value_counts()
# Out:
# Label
# 1    144
# 0    127
# Name: count, dtype: int64

# %% [markdown]
# CHECKING FOR CLASS IMBALANCE

# %%
class_counts = litob_combined['Label'].value_counts()

## percentage of each class
class_percentages = class_counts / len(litob_combined) * 100
class_percentages
# Out:
# Label
# 1    53.136531
# 0    46.863469
# Name: count, dtype: float64

# %% [markdown]
# Samples count visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')
plt.figure(figsize=(6, 5))

colors = {0: "#e9a080", 1: "#187cc1"}

ax = sns.countplot(x='Label', data=litob_combined, hue='Label', palette=colors, legend=False)
plt.xlabel('Classification (0: Female, 1: Male)', fontsize=14)
plt.ylabel('Count', fontsize=14)

plt.title('Proportion of Male and Female Litob', fontsize=16)
plt.xticks(ticks=[0, 1], labels=['Female (0)', 'Male (1)'], fontsize=12)
plt.yticks(fontsize=12)

for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),  # Converted to int
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)

plt.show()

counts = litob_combined.Label.value_counts()
proportions = counts / counts.sum()
print('Proportions of Classes:')
proportions
# Out:
# Proportions of Classes:
# Label
# 1    0.531365
# 0    0.468635
# Name: count, dtype: float64

# %% [markdown]
# CHECKING CORRELATION

# %%
litob_features = litob_combined.columns.drop(['Label'])
x = litob_combined[litob_features]
y = litob_combined['Label']

variable_corr = pd.concat([x, y], axis=1)
variable_corr
# Out:
#        Length     Width    Height  Rib count  Length (Hinge Line)  \
# 0    0.333333  0.429735  0.339114         20             0.492701
# 1    0.311667  0.221996  0.342967         20             0.476277
# 2    0.175000  0.287169  0.304432         21             0.437956
# 3    0.168333  0.244399  0.184971         21             0.308394
# 4    0.101667  0.162933  0.163776         20             0.109489
# ..        ...       ...       ...        ...                  ...
# 266  0.800000  0.814664  0.720617         20             0.733577
# 267  0.833333  0.784114  0.737958         20             0.821168
# 268  0.611667  0.708758  0.664740         19             0.666058
# 269  0.516667  0.488798  0.450867         20             0.620438
# 270  0.400000  0.386965  0.450867         20             0.498175
#
#      Distance Umbos  LW_ratio  LH_ratio  WH_ratio  UL_ratio  HL_ratio  \
# 0          0.352601  0.282637  0.463827  0.534534  0.528523  0.600949
# ...

# %%
## correlation
correlation_matrix = variable_corr.corr()

label_correlations = correlation_matrix['Label'].drop('Label')
sorted_correlations = label_correlations.abs().sort_values(ascending=False)
sorted_correlations
# Out:
# WH_ratio               0.179385
# LW_ratio               0.171232
# Distance Umbos         0.106121
# Rib Density            0.098439
# UH_ratio               0.097952
# UL_ratio               0.097314
# Length (Hinge Line)    0.095076
# Height                 0.087302
# Length                 0.084014
# HL_ratio               0.078169
# Rib count              0.075821
# LH_ratio               0.032980
# Width                  0.024582
# Name: Label, dtype: float64

# %%
codenames = {
    'Length': 'L',
    'Width': 'W',
    'Height': 'H',
    'Rib count': 'RC',
    'Length (Hinge Line)': 'LHL',
    'Distance Umbos': 'DU',
    'LW_ratio': 'LW',
    'LH_ratio': 'LH',
    'Label': 'Label',
    'WH_ratio':'WH',
    'UL_ratio':'UL',
    'HL_ratio': 'HL',
    'UH_ratio': 'UH',
    'Rib Density': 'RD'
}

label_correlations = correlation_matrix['Label'].drop('Label')
sorted_correlations = label_correlations.abs().sort_values(ascending=False)

# Create a DataFrame for the heatmap with the index as the features
label_correlations_df = pd.DataFrame(sorted_correlations)  # Convert Series to DataFrame
label_correlations_df = label_correlations_df.rename(columns={'Label': 'Correlation'}) #rename col

# Replace index with codenames in label_correlations_df
label_correlations_df.index = label_correlations_df.index.map(codenames)

# Get the minimum and maximum correlation values
vmin = label_correlations_df['Correlation'].min()
vmax = label_correlations_df['Correlation'].max()

# Plot heatmap
plt.figure(figsize=(5, 8))
sns.heatmap(label_correlations_df, annot=True, cmap='Blues', vmin=vmin, vmax=vmax, fmt=".2f", linewidths=0)  # Set vmin and vmax

# Set labels and title
plt.title('Feature Correlation with Target', fontsize=16, pad=12)
plt.ylabel('Features')

# Show the plot
plt.show()

# %% [markdown]
# CHECK FOR MULTICOLLINEARITY

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Create a new DataFrame with the selected features
X = female_litob[features]

# Add a constant column to include the intercept in the VIF calculation
X_const = add_constant(X)

# Calculate VIF for each feature
vif = pd.DataFrame()
vif['Feature'] = X_const.columns
vif['VIF'] = [variance_inflation_factor(X_const.values, i) for i in range(X_const.shape[1])]

# Display VIF values
print(vif)
# Out:
#                 Feature           VIF
# 0                 const  98959.763874
# 1                Length   1164.695046
# 2                 Width    786.461392
# 3                Height    736.218279
# 4             Rib count      6.193627
# 5   Length (Hinge Line)    335.142208
# 6        Distance Umbos     90.903705
# 7              LW_ratio    159.511085
# 8              LH_ratio    201.048577
# 9              WH_ratio    194.965057
# 10             UL_ratio    379.844945
# 11             HL_ratio     63.612502
# 12             UH_ratio    424.994037
# 13          Rib Density     59.306265

# %% [markdown]
# Correlation map

# %%
## col names and codenames
codenames = {
    'Length': 'L',
    'Width': 'W',
    'Height': 'H',
    'Rib count': 'RC',
    'Length (Hinge Line)': 'LHL',
    'Distance Umbos': 'DU',
    'LW_ratio': 'LW',
    'LH_ratio': 'LH',
    'Label': 'Label',
    'WH_ratio':'WH',
    'UL_ratio':'UL',
    'HL_ratio': 'HL',
    'UH_ratio': 'UH',
    'Rib Density': 'RD'
}

variable_corr = variable_corr.rename(columns=codenames)

## display heatmap
corr = variable_corr.corr()
plt.figure(figsize=(10, 6))
plt.title('Correlation Matrix of T. granosa variables', pad=20)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
import numpy as np
from scipy.stats import kruskal

X = litob_combined.drop('Label', axis=1)
y = litob_combined['Label']

def kruskal_wallis_feature_importance(X, y):
    feature_importance_scores = {}
    for feature in X.columns:
        groups = [X[feature][y == label] for label in y.unique()]
        statistic, p_value = kruskal(*groups)
        feature_importance_scores[feature] = statistic

    return pd.Series(feature_importance_scores).sort_values(ascending=False)

feature_importance_scores = kruskal_wallis_feature_importance(X, y)
print(feature_importance_scores)
# Out:
# WH_ratio               8.672089
# LW_ratio               6.631574
# Distance Umbos         4.475435
# UL_ratio               4.005138
# UH_ratio               3.900143
# HL_ratio               2.443852
# Length (Hinge Line)    2.424954
# Height                 2.362369
# Rib Density            2.290975
# Rib count              1.322285
# Length                 1.296331
# LH_ratio               0.256379
# Width                  0.099432
# dtype: float64

# %%
# Plotting the feature importance scores
## sorting for visualizations

codenames = {
    'Length': 'L',
    'Width': 'W',
    'Height': 'H',
    'Rib count': 'RC',
    'Length (Hinge Line)': 'LHL',
    'Distance Umbos': 'DU',
    'LW_ratio': 'LW',
    'LH_ratio': 'LH',
    'Label': 'Label',
    'WH_ratio':'WH',
    'UL_ratio':'UL',
    'HL_ratio': 'HL',
    'UH_ratio': 'UH',
    'Rib Density': 'RD'
}

sorted_features = feature_importance_scores.sort_values(ascending=False)
colors = sns.color_palette("Blues_d", len(sorted_features))
colors = colors[::-1]
plt.figure(figsize=(10, 6))

# Map codenames to sorted_featurures.index
sorted_features.index = sorted_features.index.map(codenames)

sns.barplot(x=sorted_features.values, y=sorted_features.index, hue = sorted_features.index, palette=colors,dodge=False,legend=False)
plt.xlabel("Kruskal-Wallis Statistic")
plt.ylabel("Features")
plt.title("Feature Importance based on Kruskal-Wallis Test")
plt.show()

# %% [markdown]
# DATA GROUPED BASED ON LABEL

# %%
## mean and sd by sex
grouped_data = litob_combined.groupby('Label')[features].agg(['mean', 'std'])
grouped_data
# Out:
#          Length               Width              Height            Rib count  \
#            mean       std      mean       std      mean       std       mean
# Label
# 0      0.406483  0.249717  0.444184  0.230683  0.438836  0.199556  19.740157
# 1      0.366727  0.223566  0.433415  0.208868  0.404635  0.191795  19.868056
#
#                 Length (Hinge Line)            ...  WH_ratio            \
#             std                mean       std  ...      mean       std
# Label                                          ...
# 0      0.837727            0.435197  0.228881  ...  0.395645  0.107385
# 1      0.846602            0.392706  0.217370  ...  0.438485  0.126050
#
#        UL_ratio            HL_ratio            UH_ratio           Rib Density  \
#            mean       std      mean       std      mean       std        mean
# Label
# 0      0.440743  0.169061  0.447949  0.137250  0.429663  0.165000    0.515091
# ...

# %%
## mean and std by sex
grouped_data = litob_combined.groupby('Label')[features].agg(['mean', 'std'])

## plots
plt.figure(figsize=(12, 6))
x = range(len(features))
width = 0.35
for i, sex in enumerate([0, 1]):  ## iterate through male and female

    ## multiIndex column names -> accessing colnames
    # Use list comprehension to access all means in the correct order
    means = grouped_data.loc[sex, [(feature, 'mean') for feature in features]]
    # Use list comprehension to access all stds in the correct order
    stds = grouped_data.loc[sex, [(feature, 'std') for feature in features]]
    plt.bar([xi + i * width for xi in x], means, width, yerr=stds, label=f"{'Female' if sex == 0 else 'Male'}")

## codenames x-axis labels
# Add all codenames to the dictionary.
codenames = {
    'Length': 'L',
    'Width': 'W',
    'Height': 'H',
    'Rib count': 'RC',
    'Length (Hinge Line)': 'LHL',
    'Distance Umbos': 'DU',
    'LW_ratio': 'LW',
    'LH_ratio': 'LH',
    'WH_ratio':'WH',
    'UL_ratio':'UL',
    'HL_ratio': 'HL',
    'UH_ratio': 'UH',
    'Rib Density': 'RD'
}
plt.xticks([xi + width / 2 for xi in x], [codenames.get(feature, feature) for feature in features], rotation=45, ha="right") # Use get to handle missing keys

plt.ylabel("Value")
plt.title("Mean ± SD of Features by Sex")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Extract mean and standard deviation for male and female
male_mean = descriptive_statistics['Male_Mean'].rename('Male_Mean')
female_mean = descriptive_statistics['Female_Mean'].rename('Female_Mean')
male_sd = descriptive_statistics['Male_Std'].rename('Male_Std')
female_sd = descriptive_statistics['Female_Std'].rename('Female_Std')

# Combine the desired statistics into a new DataFrame
summary_stats = pd.concat([male_mean, female_mean, male_sd, female_sd], axis=1)

# Format the DataFrame to two decimal places
summary_stats_formatted = summary_stats.applymap('{:.2f}'.format)

# Display the table
print("\nMean and Standard Deviation of Features by Sex")
display(summary_stats_formatted)
# Out:
# Mean and Standard Deviation of Features by Sex
# /tmp/ipython-input-133-3767851941.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   summary_stats_formatted = summary_stats.applymap('{:.2f}'.format)
#                     Male_Mean Female_Mean Male_Std Female_Std
# Length                  49.05       50.24     6.71       7.49
# Width                   37.69       37.95     5.13       5.66
# Height                  33.85       34.74     4.98       5.18
# Rib count               19.87       19.74     0.85       0.84
# Length (Hinge Line)     30.81       31.97     5.96       6.27
# Distance Umbos           3.50        3.80     1.50       1.35
# LW_ratio                 1.30        1.33     0.06       0.08
# LH_ratio                 1.45        1.45     0.09       0.08
# WH_ratio                 1.12        1.09     0.07       0.06
# UL_ratio                 0.07        0.07     0.03       0.02
# ...

# %% [markdown]
# ## Handling Imbalanced Dataset

# %%
# ! pip install -U imbalanced-learn

# %%
X = litob_combined.drop(['Label'], axis=1)
y = litob_combined['Label']

# %%
y.value_counts()
# Out:
# Label
# 1    144
# 0    127
# Name: count, dtype: int64

# %%
# Show pie plot
y.value_counts().plot.pie(autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# Find indices of the last 17 male rows.
male_indices = litob_combined[litob_combined['Label'] == 1].index[-17:]

# Drop those rows.
litob_combined = litob_combined.drop(male_indices)

# Check the class balance.
print(litob_combined['Label'].value_counts())
# Out:
# Label
# 0    127
# 1    127
# Name: count, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(sampling_strategy=1) # Numerical value
# rus = RandomUnderSampler(sampling_strategy="not minority") # String
X_res, y_res = rus.fit_resample(X, y)

ax = y_res.value_counts().plot.pie(autopct='%.2f')
_ = ax.set_title("Under-sampling")

# %%
# # from google.colab import files
litob_combined_resampled = pd.concat([pd.DataFrame(X_res), y_res], axis=1)
litob_combined_resampled.to_csv('litob_combined_undersampled.csv', index=False)
# # files.download('litob_combined_undersampled.csv')

# %% [markdown]
# ## **MODEL TRAINING (All Features)**

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

litob_combined_undersampled = pd.read_csv('litob_combined_undersampled.csv')

# Split features (X) and target (y)
X = litob_combined_undersampled.drop(['Label'], axis=1)
y = litob_combined_undersampled['Label']

# Define the models and their hyperparameter grids with random_state for reproducibility
models_and_grids = {
    'Logistic Regression': (LogisticRegression(random_state=42), {'C': [0.01, 0.1, 1, 10]}),
    'K-Nearest Neighbors': (KNeighborsClassifier(), {'n_neighbors': [3, 5, 7, 10], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']}),  # No random_state needed
    'Support Vector Machine': (SVC(random_state=42), {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']}),  # SVM also supports random_state
    'Random Forest': (RandomForestClassifier(random_state=42), {'n_estimators': [50, 100, 200], 'max_depth': [None, 5, 10]}),
    'AdaBoost': (AdaBoostClassifier(random_state=42), {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1]}),
    'Extra Trees': (ExtraTreesClassifier(random_state=42), {'n_estimators': [50, 100, 200], 'max_depth': [None, 5, 10]}),
    'Gradient Boosting': (GradientBoostingClassifier(random_state=42), {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]})
}

# Initialize an empty list to store the results
model_scores = []

# Loop through each model, perform grid search, and capture fold-wise CV scores
for model_name, (model, param_grid) in models_and_grids.items():
    print(f"Training {model_name}...")
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='accuracy', return_train_score=False, n_jobs=-1, verbose=1)
    grid_search.fit(X, y)

    # Get the best estimator's CV results
    best_index = grid_search.best_index_

    # Get fold scores for the best parameters only
    fold_scores = [
        grid_search.cv_results_['split0_test_score'][best_index],
        grid_search.cv_results_['split1_test_score'][best_index],
        grid_search.cv_results_['split2_test_score'][best_index],
        grid_search.cv_results_['split3_test_score'][best_index],
        grid_search.cv_results_['split4_test_score'][best_index]
    ]

    # Calculate the average score across folds
    avg_score = sum(fold_scores) / len(fold_scores)

    # Convert to percentage by multiplying by 100 for display
    fold_scores_percentage = [score * 100 for score in fold_scores]
    avg_score_percentage = avg_score * 100

    # Round each fold score individually
    fold_scores_rounded = [round(score, 2) for score in fold_scores_percentage]

    # Round the average score
    avg_score_rounded = round(avg_score_percentage, 2)

    # Append the fold scores and average score to the list
    model_scores.append({
        'Model': model_name,
        'Fold 1': fold_scores_rounded[0],
        'Fold 2': fold_scores_rounded[1],
        'Fold 3': fold_scores_rounded[2],
        'Fold 4': fold_scores_rounded[3],
        'Fold 5': fold_scores_rounded[4],
        'Average CV Score': avg_score_rounded,
        'Best Parameters': grid_search.best_params_
    })

# Create a DataFrame to display the results
scores_df = pd.DataFrame(model_scores)

# Display the table sorted by average score in descending order
scores_df = scores_df.sort_values(by='Average CV Score', ascending=False).reset_index(drop=True)

# Display the table
print("Model Comparison Based on Cross-Validation Scores (Fold-wise and Average)")
scores_df[['Model', 'Fold 1', 'Fold 2', 'Fold 3', 'Fold 4', 'Fold 5', 'Average CV Score', 'Best Parameters']]
# Out:
# Training Logistic Regression...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training K-Nearest Neighbors...
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Training Support Vector Machine...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Training Random Forest...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Training AdaBoost...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# ...

# %%
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, precision_score, recall_score, f1_score

# Define custom scoring for precision, recall, and F1
scoring = {
    'precision': make_scorer(precision_score, average='weighted'),
    'recall': make_scorer(recall_score, average='weighted'),
    'f1': make_scorer(f1_score, average='weighted')
}

# Initialize a list to store average metrics
average_metrics = []

# Loop again to use the best models from the previous grid searches
for model_data in model_scores:
    model_name = model_data['Model']
    best_params = model_data['Best Parameters']

    # Recreate the model with best parameters
    base_model, _ = models_and_grids[model_name]
    best_model = base_model.set_params(**best_params)

    # Perform cross-validation with precision, recall, f1
    cv_results = cross_validate(best_model, X, y, cv=5, scoring=scoring)

    avg_precision = round(cv_results['test_precision'].mean() * 100, 2)
    avg_recall = round(cv_results['test_recall'].mean() * 100, 2)
    avg_f1 = round(cv_results['test_f1'].mean() * 100, 2)

    average_metrics.append({
        'Model': model_name,
        'Avg Precision': avg_precision,
        'Avg Recall': avg_recall,
        'Avg F1 Score': avg_f1
    })

# Create a DataFrame for average metrics
metrics_df = pd.DataFrame(average_metrics)

# Sort by F1 Score for easy comparison
metrics_df = metrics_df.sort_values(by='Avg F1 Score', ascending=False).reset_index(drop=True)

# Display the second table
print("\nModel Comparison Based on Average Precision, Recall, and F1-Score (5-Fold CV)")
metrics_df
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ## **MODEL TRAINING (5 Features)**

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

litob_combined_undersampled = pd.read_csv('litob_combined_undersampled.csv')

# Split features (X) and target (y)
X = litob_combined_undersampled[['Distance Umbos', 'LW_ratio', 'WH_ratio', 'UL_ratio', 'UH_ratio']]
y = litob_combined_undersampled['Label']

# Define the models and their hyperparameter grids with random_state for reproducibility
models_and_grids = {
    'Logistic Regression': (LogisticRegression(random_state=42), {'C': [0.01, 0.1, 1, 10]}),
    'K-Nearest Neighbors': (KNeighborsClassifier(), {'n_neighbors': [3, 5, 7, 10], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']}),
    'Support Vector Machine': (SVC(random_state=42), {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']}),
    'Random Forest': (RandomForestClassifier(random_state=42), {'n_estimators': [50, 100, 200], 'max_depth': [None, 5, 10]}),
    'AdaBoost': (AdaBoostClassifier(random_state=42), {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 1]}),
    'Extra Trees': (ExtraTreesClassifier(random_state=42), {'n_estimators': [50, 100, 200], 'max_depth': [None, 5, 10]}),
    'Gradient Boosting': (GradientBoostingClassifier(random_state=42), {'n_estimators': [50, 100, 200], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]})
}

# Initialize an empty list to store the results
model_scores = []

# Loop through each model, perform grid search, and capture fold-wise CV scores
for model_name, (model, param_grid) in models_and_grids.items():
    print(f"Training {model_name}...")
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='accuracy', return_train_score=False, n_jobs=-1, verbose=1)
    grid_search.fit(X, y)

    # Get the best estimator's CV results
    best_index = grid_search.best_index_

    # Get fold scores for the best parameters only
    fold_scores = [
        grid_search.cv_results_['split0_test_score'][best_index],
        grid_search.cv_results_['split1_test_score'][best_index],
        grid_search.cv_results_['split2_test_score'][best_index],
        grid_search.cv_results_['split3_test_score'][best_index],
        grid_search.cv_results_['split4_test_score'][best_index]
    ]

    # Calculate the average score across folds
    avg_score = sum(fold_scores) / len(fold_scores)

    # Convert to percentage by multiplying by 100 for display
    fold_scores_percentage = [score * 100 for score in fold_scores]
    avg_score_percentage = avg_score * 100

    # Round each fold score individually
    fold_scores_rounded = [round(score, 2) for score in fold_scores_percentage]

    # Round the average score
    avg_score_rounded = round(avg_score_percentage, 2)

    # Append the fold scores and average score to the list
    model_scores.append({
        'Model': model_name,
        'Fold 1': fold_scores_rounded[0],
        'Fold 2': fold_scores_rounded[1],
        'Fold 3': fold_scores_rounded[2],
        'Fold 4': fold_scores_rounded[3],
        'Fold 5': fold_scores_rounded[4],
        'Average CV Score': avg_score_rounded,
        'Best Parameters': grid_search.best_params_
    })

# Create a DataFrame to display the results
scores_df = pd.DataFrame(model_scores)

# Display the table sorted by average score in descending order
scores_df = scores_df.sort_values(by='Average CV Score', ascending=False).reset_index(drop=True)

# Display the table
print("Model Comparison Based on Cross-Validation Scores (Fold-wise and Average)")
scores_df[['Model', 'Fold 1', 'Fold 2', 'Fold 3', 'Fold 4', 'Fold 5', 'Average CV Score', 'Best Parameters']]
# Out:
# Training Logistic Regression...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Training K-Nearest Neighbors...
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Training Support Vector Machine...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Training Random Forest...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Training AdaBoost...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Training Extra Trees...
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Training Gradient Boosting...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Model Comparison Based on Cross-Validation Scores (Fold-wise and Average)
#                     Model  Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  \
# 0       Gradient Boosting   72.55   58.82   56.86   60.78    66.0
# 1  Support Vector Machine   54.90   50.98   58.82   68.63    76.0
# ...

# %%
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, precision_score, recall_score, f1_score

# Define custom scoring for precision, recall, and F1
scoring = {
    'precision': make_scorer(precision_score, average='weighted'),
    'recall': make_scorer(recall_score, average='weighted'),
    'f1': make_scorer(f1_score, average='weighted')
}

# Initialize a list to store average metrics
average_metrics = []

# Loop again to use the best models from the previous grid searches
for model_data in model_scores:
    model_name = model_data['Model']
    best_params = model_data['Best Parameters']

    # Recreate the model with best parameters
    base_model, _ = models_and_grids[model_name]
    best_model = base_model.set_params(**best_params)

    # Perform cross-validation with precision, recall, f1
    cv_results = cross_validate(best_model, X, y, cv=5, scoring=scoring)

    avg_precision = round(cv_results['test_precision'].mean() * 100, 2)
    avg_recall = round(cv_results['test_recall'].mean() * 100, 2)
    avg_f1 = round(cv_results['test_f1'].mean() * 100, 2)

    average_metrics.append({
        'Model': model_name,
        'Avg Precision': avg_precision,
        'Avg Recall': avg_recall,
        'Avg F1 Score': avg_f1
    })

# Create a DataFrame for average metrics
metrics_df = pd.DataFrame(average_metrics)

# Sort by F1 Score for easy comparison
metrics_df = metrics_df.sort_values(by='Avg F1 Score', ascending=False).reset_index(drop=True)

# Display the second table
print("\nModel Comparison Based on Average Precision, Recall, and F1-Score (5-Fold CV)")
metrics_df
# Out:
# Model Comparison Based on Average Precision, Recall, and F1-Score (5-Fold CV)
#                     Model  Avg Precision  Avg Recall  Avg F1 Score
# 0       Gradient Boosting          63.22       63.00         62.88
# 1     K-Nearest Neighbors          61.19       61.07         60.99
# 2  Support Vector Machine          64.05       61.87         60.73
# 3             Extra Trees          61.72       61.07         60.22
# 4           Random Forest          60.02       59.90         59.60
# 5                AdaBoost          59.38       58.29         57.31
# 6     Logistic Regression          61.45       55.95         50.97

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # Needed for the heatmap
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Load dataset
df = pd.read_csv('litob_combined_undersampled.csv')

# Select features and label
X = df[['Distance Umbos', 'LW_ratio', 'WH_ratio', 'UL_ratio', 'UH_ratio']]
y = df['Label']

# Get the best model and parameters
best_model_name = scores_df.iloc[0]['Model']
base_model, _ = models_and_grids[best_model_name]
best_params = scores_df.iloc[0]['Best Parameters']
best_model = base_model.set_params(**best_params)

print(f"Generating confusion matrix for the best model: {best_model_name}")

# Predict using cross-validation
y_pred = cross_val_predict(best_model, X, y, cv=5)

# Compute confusion matrix
cm = confusion_matrix(y, y_pred, labels=[0, 1])

# Normalize the confusion matrix
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100
cm_norm = np.round(cm_norm, 0).astype(int)  # Round percentages

# Combine raw counts and percentages in annotations
annot = np.empty_like(cm, dtype=object)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        annot[i, j] = f'{cm[i, j]}\n({cm_norm[i, j]}%)'

# Plot confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=annot, fmt='', cmap='Blues',
            xticklabels=['Female (0)', 'Male (1)'],
            yticklabels=['Female (0)', 'Male (1)'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title(f'Confusion Matrix for {best_model_name}')
plt.tight_layout()
plt.show()

# Print classification report
print("\nCross-Validated Classification Report:")
print(classification_report(y, y_pred, target_names=['Female (0)', 'Male (1)']))

# Print accuracy
cv_accuracy = accuracy_score(y, y_pred) * 100
print(f"\nCross-Validated Accuracy: {cv_accuracy:.2f}%")
# Out:
# Generating confusion matrix for the best model: Gradient Boosting
# Cross-Validated Classification Report:
#               precision    recall  f1-score   support
#
#   Female (0)       0.63      0.65      0.64       127
#     Male (1)       0.63      0.61      0.62       127
#
#     accuracy                           0.63       254
#    macro avg       0.63      0.63      0.63       254
# weighted avg       0.63      0.63      0.63       254
#
#
# Cross-Validated Accuracy: 62.99%

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import numpy as np
from sklearn.model_selection import cross_val_predict

# Get the best model and parameters from the previous grid search
best_model_name = scores_df.iloc[0]['Model']
base_model, _ = models_and_grids[best_model_name]
best_params = scores_df.iloc[0]['Best Parameters']
best_model = base_model.set_params(**best_params)

print(f"Generating ROC curve for the best model: {best_model_name}")

try:
    y_scores = cross_val_predict(best_model, X, y, cv=5, method='predict_proba')[:, 1]
except AttributeError:
    print("Model does not have predict_proba. Using decision_function if available.")
    try:
        y_scores = cross_val_predict(best_model, X, y, cv=5, method='decision_function')
    except AttributeError:
        print("Model does not have decision_function either. Cannot plot ROC curve.")
        y_scores = None


if y_scores is not None:
    # Compute ROC curve and AUC
    fpr, tpr, _ = roc_curve(y, y_scores)
    roc_auc = auc(fpr, tpr)

    plt.style.use('seaborn-v0_8-white')
    fig, ax = plt.subplots(figsize=(8, 6)) #

    ax.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % (roc_auc * 100))
    ax.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel("False Positive Rate")
    ax.set_ylabel("True Positive Rate")
    ax.set_title("ROC Curve")
    ax.legend(loc="lower right")

    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)

    plt.show()
# Out:
# Generating ROC curve for the best model: Gradient Boosting
